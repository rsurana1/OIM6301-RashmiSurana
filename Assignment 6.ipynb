# %% [markdown]
# <a href="https://colab.research.google.com/github/rsurana1/OIM6301-RashmiSurana/blob/main/Assignment%206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================
# Exercise 01
# =========================

print("EXERCISE 01 OUTPUTS")

# Valid print statement
print("Hello, World")

# Plus sign before numbers
print(+2)
print(2++2)

# print 'Hello'              # SyntaxError: missing parentheses
# print(Hello)               # NameError: Hello not defined
# print('Hello)              # SyntaxError: unterminated string
# 02                          # SyntaxError: leading zeros not allowed
# 2 3                         # SyntaxError: missing operator

print("\nExercise 01 completed.\n")

# =========================
# Exercise 02
# =========================

print("EXERCISE 02 OUTPUTS")

# Given values
minutes = 42
seconds = 42
kilometers = 10
km_per_mile = 1.61

# Total seconds
total_seconds = minutes * 60 + seconds

# Convert kilometers to miles
miles = kilometers / km_per_mile

# Average pace (time per mile)
pace_seconds = total_seconds / miles
pace_minutes = int(pace_seconds // 60)
pace_remaining_seconds = pace_seconds % 60

# Average speed (miles per hour)
time_hours = total_seconds / 3600
speed_mph = miles / time_hours

# Print results
print("Total seconds:", total_seconds)
print("Miles in 10 kilometers:", round(miles, 2))
print("Average pace:", pace_minutes, "minutes", round(pace_remaining_seconds, 1), "seconds per mile")
print("Average speed:", round(speed_mph, 2), "miles per hour")
# Out:
# EXERCISE 01 OUTPUTS
# Hello, World
# 2
# 4
#
# Exercise 01 completed.
#
# EXERCISE 02 OUTPUTS
# Total seconds: 2562
# Miles in 10 kilometers: 6.21
# Average pace: 6 minutes 52.5 seconds per mile
# Average speed: 8.73 miles per hour
